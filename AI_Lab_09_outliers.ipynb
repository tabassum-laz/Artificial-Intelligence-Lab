# %% [markdown]
# <a href="https://colab.research.google.com/github/tabassum-laz/Artificial-Intelligence-Lab/blob/main/AI_Lab_09_outliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Artificial Intelligence/ML/Data/placement.csv')

# %%
df.shape
# Out:
# (1000, 3)

# %%
df.sample(10)
# Out:
#      cgpa  placement_exam_marks  placed
# 142  7.66                  41.0       1
# 779  6.39                  32.0       0
# 85   6.03                  28.0       0
# 285  7.42                  57.0       1
# 184  7.78                  33.0       0
# 582  7.05                  27.0       1
# 20   6.69                  47.0       0
# 398  7.55                  48.0       0
# 444  6.66                  14.0       1
# 243  6.78                  55.0       0

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['placement_exam_marks'])
plt.show()

# %%
df['cgpa'].skew()
# Out:
# -0.014529938929314918

# %%
print("Mean value of cgpa",df['cgpa'].mean())
print("Std value of cgpa",df['cgpa'].std())
print("Min value of cgpa",df['cgpa'].min())
print("Max value of cgpa",df['cgpa'].max())
# Out:
# Mean value of cgpa 6.96124
# Std value of cgpa 0.6158978751323896
# Min value of cgpa 4.89
# Max value of cgpa 9.12

# %%
#handling oulier using mean and std
# upper limit= mean + 3*std
# lower limit= mean - 3*std

# %%
# Finding the boundary values
upper_limit= df['cgpa'].mean() + 3*df['cgpa'].std()
lower_limit= df['cgpa'].mean() - 3*df['cgpa'].std()

# %%
print('Upper Limit: ',upper_limit)
print('Lower Limit: ',lower_limit)
# Out:
# Upper Limit:  8.808933625397168
# Lower Limit:  5.113546374602832

# %%
# Finding outlier    # or = |
outlier = df[(df['cgpa'] > upper_limit) | (df['cgpa'] < lower_limit)]
outlier
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %%
df.shape
# Out:
# (1000, 3)

# %%
# Removing outlier
# trimming (process of delete outlier from dataset)
new_df = df[(df['cgpa'] < upper_limit) & (df['cgpa'] > lower_limit)]
new_df.shape
# Out:
# (995, 3)

# %% [markdown]
# **Handling outliers using the Zscore**

# %%
#handling outliers using Zscore
# z = (x- mean)/std

# %%
# Finding the z score
df['cgpa_zscore'] = (df['cgpa'] - df['cgpa'].mean())/df['cgpa'].std()

# %%
# Finding outlier
# if zscore greater than 3 and less than -3 then this will be outlier
outlier = df[(df['cgpa_zscore'] > 3) | (df['cgpa_zscore'] < -3)]
outlier
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 485  4.92                  44.0       1    -3.314251
# 995  8.87                  44.0       1     3.099150
# 996  9.12                  65.0       1     3.505062
# 997  4.89                  34.0       0    -3.362960
# 999  4.90                  10.0       1    -3.346724

# %%
# trimming (process of delete outlier from dataset)
new_df1 = df[(df['cgpa_zscore'] < 3 ) & (df['cgpa_zscore'] > -3)]
new_df1.shape
# Out:
# (995, 4)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['cgpa'])

plt.subplot(2,2,2)
sns.boxplot(df['cgpa'])

plt.subplot(2,2,3)
sns.distplot(new_df1['cgpa'])

plt.subplot(2,2,4)
sns.boxplot(new_df1['cgpa'])
# Out:
# <Axes: >

# %% [markdown]
# # **Capping**

# %%
#replace outliers, if outliers greater than upper limit then replace it by upper limit, if outliers less than lower limit then replace it by lower limit
#np.where(condition, true, false)
df2=df.copy()
df2['cgpa'] = np.where(
    df2['cgpa']>upper_limit,
    upper_limit,
    np.where(
        df2['cgpa']<lower_limit,
        lower_limit,
        df2['cgpa']
    )
)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['cgpa'])

plt.subplot(2,2,2)
sns.boxplot(df['cgpa'])

plt.subplot(2,2,3)
sns.distplot(df2['cgpa'])

plt.subplot(2,2,4)
sns.boxplot(df2['cgpa'])
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (1000, 4)

# %%
df['cgpa'].describe()
# Out:
# count    1000.000000
# mean        6.961240
# std         0.615898
# min         4.890000
# 25%         6.550000
# 50%         6.960000
# 75%         7.370000
# max         9.120000
# Name: cgpa, dtype: float64

# %% [markdown]
# # **Outlier in Skewed distribution (placement_exam_marks)**

# %%
df['placement_exam_marks'].skew() #Left Skewed
# Out:
# 0.8356419499466834

# %%
df['placement_exam_marks'].describe()
# Out:
# count    1000.000000
# mean       32.225000
# std        19.130822
# min         0.000000
# 25%        17.000000
# 50%        28.000000
# 75%        44.000000
# max       100.000000
# Name: placement_exam_marks, dtype: float64

# %%
sns.boxplot(df['placement_exam_marks'])
# Out:
# <Axes: >

# %%
# Finding the IQR
percentile25 = df['placement_exam_marks'].quantile(0.25)
percentile75 = df['placement_exam_marks'].quantile(0.75)

# %%
iqr=percentile75-percentile25
iqr
# Out:
# 27.0

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

# %%
outlier= df[(df['placement_exam_marks']>upper_limit) |
         (df['placement_exam_marks']<lower_limit)]
outlier.shape
# Out:
# (15, 4)

# %% [markdown]
# # **Trimming**

# %%
new_df2 = df[(df['placement_exam_marks']<upper_limit) &
         (df['placement_exam_marks']>lower_limit)]

new_df2
# Out:
#      cgpa  placement_exam_marks  placed  cgpa_zscore
# 0    7.19                  26.0       1     0.371425
# 1    7.46                  38.0       1     0.809810
# 2    7.54                  40.0       1     0.939701
# 3    6.42                   8.0       1    -0.878782
# 4    7.23                  17.0       0     0.436371
# ..    ...                   ...     ...          ...
# 995  8.87                  44.0       1     3.099150
# 996  9.12                  65.0       1     3.505062
# 997  4.89                  34.0       0    -3.362960
# 998  8.62                  46.0       1     2.693239
# 999  4.90                  10.0       1    -3.346724
#
# [985 rows x 4 columns]

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(new_df2['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(new_df2['placement_exam_marks'])
# Out:
# <Axes: >

# %% [markdown]
# # **Capping**

# %%
df1 = df.copy()
df1['placement_exam_marks'] = np.where(
    df1['placement_exam_marks'] > upper_limit,
    upper_limit,
    np.where(
       df1['placement_exam_marks'] < lower_limit,
        lower_limit,
        df1['placement_exam_marks']
    )
)
df1.shape
# Out:
# (1000, 4)

# %%
# Comparing

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['placement_exam_marks'])

plt.subplot(2,2,2)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(2,2,3)
sns.distplot(df1['placement_exam_marks'])

plt.subplot(2,2,4)
sns.boxplot(df1['placement_exam_marks'])
# Out:
# <Axes: >
